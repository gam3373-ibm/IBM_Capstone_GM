# %%
# !pip install dash
# !pip install dash==1.19.0!
# !pip install jupyter_dash
# !pip install --upgrade plotly

import pandas as pd
import plotly.graph_objects as go
import dash
import dash_html_components as html
#import dash_core_components as dcc
from dash import dcc
from dash.dependencies import Input, Output
import plotly.express as px
# Out:
# Requirement already satisfied: dash in c:\users\grego\anaconda3\lib\site-packages (2.6.2)
# Requirement already satisfied: flask-compress in c:\users\grego\anaconda3\lib\site-packages (from dash) (1.13)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\grego\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\grego\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\grego\anaconda3\lib\site-packages (from dash) (5.11.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\grego\anaconda3\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\grego\anaconda3\lib\site-packages (from dash) (1.1.2)
# Requirement already satisfied: click>=5.1 in c:\users\grego\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (8.0.4)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\grego\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\grego\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\grego\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: colorama in c:\users\grego\anaconda3\lib\site-packages (from click>=5.1->Flask>=1.0.4->dash) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\grego\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\grego\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Requirement already satisfied: brotli in c:\users\grego\anaconda3\lib\site-packages (from flask-compress->dash) (1.0.9)
# ERROR: Could not find a version that satisfies the requirement dash==1.19.0! (from versions: 0.17.4, 0.17.5, 0.17.7, 0.17.8rc1, 0.17.8rc2, 0.17.8rc3, 0.18.0, 0.18.1, 0.18.2, 0.18.3rc1, 0.18.3, 0.19.0, 0.20.0, 0.21.0, 0.21.1, 0.22.0rc1, 0.22.0rc2, 0.22.0, 0.23.1, 0.24.0, 0.24.1rc1, 0.24.1, 0.24.2, 0.25.0, 0.25.1, 0.26.0, 0.26.1rc1, 0.26.1rc2, 0.26.1rc3, 0.26.1, 0.26.2, 0.26.3, 0.26.4, 0.26.5, 0.26.6, 0.27.0rc1, 0.27.0rc2, 0.27.0rc3, 0.27.0rc4, 0.27.0rc5, 0.27.0rc6, 0.27.0rc7, 0.27.0rc8, 0.27.0rc9, 0.27.0, 0.28.0, 0.28.1, 0.28.2, 0.28.3, 0.28.4, 0.28.5, 0.28.6, 0.28.7, 0.29.0rc1, 0.29.0rc2, 0.29.0rc3, 0.29.0rc4, 0.29.0rc5, 0.29.0rc6, 0.29rc7, 0.29.0rc8, 0.29.0, 0.30.0rc1, 0.30.0rc2, 0.30.0rc3, 0.30.0rc4, 0.30.0rc5, 0.30.0, 0.31.0rc1, 0.31.0rc2, 0.31.0, 0.31.1, 0.32.0rc1, 0.32.0rc2, 0.32.0, 0.32.1, 0.32.2, 0.34.0, 0.35.0rc1, 0.35.0, 0.35.1, 0.35.2, 0.35.3, 0.36.0rc1, 0.36.0, 0.37.0rc1, 0.37.0rc2, 0.37.0, 0.38.0rc1, 0.38.0, 0.39.0, 0.40.0rc1, 0.40.0, 0.41.0, 0.42.0, 0.43.0rc1, 0.43.0rc2, 0.43.0rc3, 0.43.0, 1.0.0a1, 1.0.0, 1.0.1rc1, 1.0.1, 1.0.2, 1.1.0, 1.1.1, 1.2.0, 1.3.0, 1.3.1, 1.4.0, 1.4.1, 1.5.0, 1.5.1, 1.6.0, 1.6.1, 1.7.0, 1.8.0, 1.9.0, 1.9.1, 1.10.0, 1.11.0, 1.12.0, 1.13.0, 1.13.1, 1.13.2, 1.13.3, 1.13.4, 1.14.0, 1.15.0, 1.16.0, 1.16.1, 1.16.2, 1.16.3, 1.17.0, 1.18.0, 1.18.1, 1.19.0, 1.20.0, 1.21.0, 2.0.0rc1, 2.0.0rc2, 2.0.0rc3, 2.0.0, 2.1.0, 2.2.0, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.6.1, 2.6.2, 2.7.0)
# ERROR: No matching distribution found for dash==1.19.0!
# Requirement already satisfied: jupyter_dash in c:\users\grego\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: ipykernel in c:\users\grego\anaconda3\lib\site-packages (from jupyter_dash) (6.9.1)
# Requirement already satisfied: ipython in c:\users\grego\anaconda3\lib\site-packages (from jupyter_dash) (8.2.0)
# Requirement already satisfied: dash in c:\users\grego\anaconda3\lib\site-packages (from jupyter_dash) (2.6.2)
# Requirement already satisfied: requests in c:\users\grego\anaconda3\lib\site-packages (from jupyter_dash) (2.27.1)
# Requirement already satisfied: ansi2html in c:\users\grego\anaconda3\lib\site-packages (from jupyter_dash) (1.8.0)
# Requirement already satisfied: retrying in c:\users\grego\anaconda3\lib\site-packages (from jupyter_dash) (1.3.3)
# Requirement already satisfied: nest-asyncio in c:\users\grego\anaconda3\lib\site-packages (from jupyter_dash) (1.5.5)
# Requirement already satisfied: flask in c:\users\grego\anaconda3\lib\site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\grego\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.11.0)
# Requirement already satisfied: flask-compress in c:\users\grego\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.13)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\grego\anaconda3\lib\site-packages (from dash->jupyter_dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\grego\anaconda3\lib\site-packages (from dash->jupyter_dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\grego\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.0.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\grego\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\grego\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\grego\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\grego\anaconda3\lib\site-packages (from flask->jupyter_dash) (8.0.4)
# Requirement already satisfied: colorama in c:\users\grego\anaconda3\lib\site-packages (from click>=5.1->flask->jupyter_dash) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\grego\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\grego\anaconda3\lib\site-packages (from plotly>=5.0.0->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: brotli in c:\users\grego\anaconda3\lib\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in c:\users\grego\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.1.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\grego\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\grego\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (1.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\grego\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (0.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\grego\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: pickleshare in c:\users\grego\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\grego\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\users\grego\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\grego\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: backcall in c:\users\grego\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\grego\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.11.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\grego\anaconda3\lib\site-packages (from ipython->jupyter_dash) (61.2.0)
# Requirement already satisfied: decorator in c:\users\grego\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\grego\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\grego\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\grego\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\grego\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\grego\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter_dash) (302)
# Requirement already satisfied: wcwidth in c:\users\grego\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\grego\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel->jupyter_dash) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\grego\anaconda3\lib\site-packages (from requests->jupyter_dash) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\grego\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\grego\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\grego\anaconda3\lib\site-packages (from requests->jupyter_dash) (3.3)
# Requirement already satisfied: executing in c:\users\grego\anaconda3\lib\site-packages (from stack-data->ipython->jupyter_dash) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\grego\anaconda3\lib\site-packages (from stack-data->ipython->jupyter_dash) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\grego\anaconda3\lib\site-packages (from stack-data->ipython->jupyter_dash) (0.2.2)
# Requirement already satisfied: plotly in c:\users\grego\anaconda3\lib\site-packages (5.11.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\grego\anaconda3\lib\site-packages (from plotly) (8.0.1)
# C:\Users\grego\AppData\Local\Temp\ipykernel_15568\122495630.py:9: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
#import pandas as pd
spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

#spacex_df

# %%
# Create a dash application
app = dash.Dash(__name__)
#app = JupyterDash(__name__) 

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                html.Div(
                                    dcc.Dropdown(id='site-dropdown',
                                                 options=[
                                                    {'label': 'All Sites', 'value': 'ALL'},
                                                    {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                                    {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                                    {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                                    {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},],
                                                 value = 'ALL',
                                                 placeholder = "Launch Sites",
                                                 searchable=True
                                                    )
                                        ),
                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                dcc.RangeSlider(id='payload-slider',
                                                min=0, max=10000, step=1000,
                                                marks={0: '0 Kg',
                                                    2000: '2000',
                                                    4000: '4000',
                                                    6000: '6000',
                                                    8000: '8000',
                                                    10000: '10000',},
                                                value=[min_payload, max_payload]),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
#@app.callback( Output(component_id='success-pie-chart', component_property='figure'), 
#                Input(component_id='site-dropdown', component_property='value'))

@app.callback(Output(component_id='success-pie-chart', component_property='figure'), 
              Input(component_id='site-dropdown', component_property='value'))

def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', names='Launch Site', title='Launch Site Success Counts')
        #return fig
    else:
        # return the outcomes piechart for a selected site
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        filtered_df = filtered_df.groupby('class').count().reset_index()
        fig = px.pie(filtered_df,values='Unnamed: 0',names='class',title='Total Launches for site {}'.format(entered_site))
       
    return fig


@app.callback(Output(component_id='success-payload-scatter-chart', component_property='figure'),
                [Input(component_id='site-dropdown', component_property='value'), 
                Input(component_id="payload-slider", component_property="value")])

def get_scatter(entered_site, slider_range):

    low, high = slider_range
    slide=(spacex_df['Payload Mass (kg)'] > low) & (spacex_df['Payload Mass (kg)'] < high)
    dropdown_scatter=spacex_df[slide]

    if entered_site == 'ALL':
        fig= px.scatter(
            dropdown_scatter, x="Payload Mass (kg)", y="class",
            color="Booster Version Category",
            hover_data=['Booster Version'],
            title="Correlation between Payload and Success for all Sites")
        return fig
    else:
        dropdown_scatter = dropdown_scatter[spacex_df['Launch Site'] == entered_site]
        title_scatter = f'Success by Payload Size for {entered_site}'
        fig=px.scatter(dropdown_scatter,x="Payload Mass (kg)", y="class", title = title_scatter, color='Booster Version Category')
        return fig

# %%
# Run the app
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [04/Dec/2022 16:59:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Dec/2022 16:59:39] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Dec/2022 16:59:40] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Dec/2022 16:59:40] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [04/Dec/2022 16:59:40] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [04/Dec/2022 16:59:40] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 304 -
# 127.0.0.1 - - [04/Dec/2022 16:59:40] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [04/Dec/2022 16:59:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Dec/2022 16:59:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Dec/2022 16:59:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Dec/2022 17:00:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Dec/2022 17:00:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Dec/2022 17:02:13] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\grego\AppData\Local\Temp\ipykernel_15568\786243722.py:85: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [04/Dec/2022 17:02:13] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\grego\AppData\Local\Temp\ipykernel_15568\786243722.py:85: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [04/Dec/2022 17:02:18] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\grego\AppData\Local\Temp\ipykernel_15568\786243722.py:85: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [04/Dec/2022 17:02:21] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\grego\AppData\Local\Temp\ipykernel_15568\786243722.py:85: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [04/Dec/2022 17:02:24] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\grego\AppData\Local\Temp\ipykernel_15568\786243722.py:85: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [04/Dec/2022 17:02:26] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\grego\AppData\Local\Temp\ipykernel_15568\786243722.py:85: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [04/Dec/2022 17:02:32] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\grego\AppData\Local\Temp\ipykernel_15568\786243722.py:85: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [04/Dec/2022 17:02:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Dec/2022 17:02:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Dec/2022 17:02:37] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\grego\AppData\Local\Temp\ipykernel_15568\786243722.py:85: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [04/Dec/2022 17:03:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Dec/2022 17:03:51] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\grego\AppData\Local\Temp\ipykernel_15568\786243722.py:85: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [04/Dec/2022 17:04:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Dec/2022 17:04:03] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\grego\AppData\Local\Temp\ipykernel_15568\786243722.py:85: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [04/Dec/2022 17:04:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Dec/2022 17:04:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Dec/2022 17:04:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Dec/2022 17:04:18] "POST /_dash-update-component HTTP/1.1" 200 -
